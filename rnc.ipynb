# %%
# !pip install python-stdnum zeep simplejson pycountry
# Out:
# UsageError: Line magic function `%python3.12` not found.

# %%
import requests
from urllib3.exceptions import InsecureRequestWarning
from stdnum.do import rnc
# Deshabilitar advertencias de SSL
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# Hacer la llamada sin verificación de SSL
rnc.search_dgii('digital', end_at=20, start_at=1)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/Documents/practice/python/data_science/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/Documents/practice/python/data_science/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...

# %%
import certifi
from stdnum.do import rnc
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.ssl_ import create_urllib3_context

# Configurar una sesión con certificados actualizados
session = requests.Session()
session.verify = certifi.where()

# Asumiendo que stdnum.do.rnc.search_dgii usa requests internamente,
# podrías necesitar configurar globalmente o modificar la librería.

# Ejecutar la búsqueda
rnc.search_dgii('digital', end_at=20, start_at=1)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/Documents/practice/python/data_science/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/Documents/practice/python/data_science/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...

# %%
import certifi
from stdnum.do import rnc
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.ssl_ import create_urllib3_context

# Configurar una sesión con certificados actualizados
session = requests.Session()
session.verify = certifi.where()

# Asumiendo que stdnum.do.rnc.search_dgii usa requests internamente,
# podrías necesitar configurar globalmente o modificar la librería.

# Ejecutar la búsqueda
rnc.search_dgii('digital', end_at=20, start_at=1)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/Documents/practice/python/data_science/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/Documents/practice/python/data_science/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...
